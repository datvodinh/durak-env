# %%
from env import *

# %%
numba_main_2(random_player,100000,0,0)

# %%
# !python env_print.py
# Out:
# P1: 6♤ 2♧ 3♧ 5♧ K♧ 2♢ 8♢ J♡
# P2: 5♤ 8♧ J♧ Q♢ A♢ 6♡ 8♡ A♡
# P3: 8♤ A♤ 4♧ A♧ 3♢ 6♢ 5♡ 9♡
# P4: K♤ 6♧ 9♧ 9♢ J♢ K♢ 3♡ K♡
# Turn 0; Trump card: 5♢; Defend id: 2.0; Attack id :1.0; Player: 1 is attacking;
# List action: [6♤ 2♧ 3♧ 5♧ K♧ 2♢ 8♢ J♡ ]
# Action index: 3♧; Player attack
#
# ---------------------------------------
#
# P1: 6♤ 2♧ 5♧ K♧ 2♢ 8♢ J♡
# P2: 5♤ 8♧ J♧ Q♢ A♢ 6♡ 8♡ A♡
# P3: 8♤ A♤ 4♧ A♧ 3♢ 6♢ 5♡ 9♡
# P4: K♤ 6♧ 9♧ 9♢ J♢ K♢ 3♡ K♡
# Turn 1; Trump card: 5♢; Defend id: 2.0; Attack id :1.0; Player: 2 is defending;
# List action: [8♧ J♧ Q♢ A♢ skip ]
# Action index: J♧; Defend successful
#
# ---------------------------------------
#
# P1: 6♤ 2♧ 5♧ K♧ 2♢ 8♢ J♡
# P2: 5♤ 8♧ Q♢ A♢ 6♡ 8♡ A♡
# P3: 8♤ A♤ 4♧ A♧ 3♢ 6♢ 5♡ 9♡
# P4: K♤ 6♧ 9♧ 9♢ J♢ K♢ 3♡ K♡
# Turn 2; Trump card: 5♢; Defend id: 2.0; Attack id :1.0; Player: 1 is attacking;
# List action: [J♡ skip ]
# Action index: J♡; Player attack
#
# ---------------------------------------
#
# P1: 6♤ 2♧ 5♧ K♧ 2♢ 8♢
# P2: 5♤ 8♧ Q♢ A♢ 6♡ 8♡ A♡
# ...
